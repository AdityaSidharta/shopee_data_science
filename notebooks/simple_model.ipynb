# %%
# %cd /home/adityasidharta/git/shopee_data_science
# %env PROJECT_PATH /home/adityasidharta/git/shopee_data_science
# Out:
# /home/adityasidharta/git/shopee_data_science
# env: PROJECT_PATH=/home/adityasidharta/git/shopee_data_science

# %%
from utils.envs import *
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from category_encoders import OrdinalEncoder
from sklearn.model_selection import train_test_split
import xgboost as xgb
import lightgbm as lgb
import string

# %%
beauty_train = pd.read_csv(beauty_train_repo)
beauty_val = pd.read_csv(beauty_val_repo)

fashion_train = pd.read_csv(fashion_train_repo)
fashion_val = pd.read_csv(fashion_val_repo)

mobile_train = pd.read_csv(mobile_train_repo)
mobile_val = pd.read_csv(mobile_val_repo)

# %%
print(beauty_train.columns)
print(fashion_train.columns)
print(mobile_train.columns)
# Out:
# Index(['itemid', 'title', 'image_path', 'Colour_group', 'Brand', 'Benefits',
#        'Product_texture', 'Skin_type'],
#       dtype='object')
# Index(['itemid', 'title', 'Pattern', 'Collar Type', 'Sleeves', 'Fashion Trend',
#        'Clothing Material', 'image_path'],
#       dtype='object')
# Index(['itemid', 'title', 'image_path', 'Operating System', 'Features',
#        'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
#        'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
#        'Phone Screen Size'],
#       dtype='object')

# %%
print(beauty_val.columns)
print(fashion_val.columns)
print(mobile_val.columns)
# Out:
# Index(['itemid', 'title', 'image_path'], dtype='object')
# Index(['itemid', 'title', 'image_path'], dtype='object')
# Index(['itemid', 'title', 'image_path'], dtype='object')

# %%
def text_process(s):
    s = str(s)
    s.translate(str.maketrans('','',string.punctuation))
    s = s.lower()
    return s

# %%
feature_encoder = TfidfVectorizer()
beauty_train['title'].values
# Out:
# array(['nyx sex bomb pallete natural palette',
#        'etude house precious mineral any cushion pearl aura puff',
#        'milani rose powder blush', ..., 'tony moly delight tint mini red',
#        'nyx soft matte lip cream smlc shade san paolo',
#        'liquid lipstick anastasia beverly hills matte colour'],
#       dtype=object)

# %%
def create_label(df, test_df, topic):
    result_dict = {}
    feature_df = df[['title']].copy()
    label_df = df.drop(columns=['itemid', 'title', 'image_path']).copy()
    
    feature_df['title'] = feature_df['title'].apply(lambda x: text_process(x))
    feature_array = feature_df['title'].values.tolist()
    feature_encoder = TfidfVectorizer()
    feature_encoder.fit(feature_array)
    feature_attr = feature_encoder.transform(feature_array)
    feature_decomposer = TruncatedSVD(500)
    feature_decomposer.fit(feature_attr)
    feature_attr = feature_decomposer.transform(feature_attr)
    
    test_df['title'] = test_df['title'].apply(lambda x: text_process(x))
    test_array = test_df['title'].values.tolist()
    test_attr = feature_encoder.transform(test_array)
    test_attr = feature_decomposer.transform(test_attr)
    
    train_itemid = df['itemid']
    test_itemid = test_df['itemid']
    
    result_dict['itemid_train_{}'.format(topic)] = train_itemid
    result_dict['itemid_test_{}'.format(topic)] = test_itemid
    result_dict['X_train_{}'.format(topic)] = feature_attr
    result_dict['X_encoder_{}'.format(topic)] = feature_encoder
    result_dict['X_decomposer_{}'.format(topic)] = feature_decomposer
    result_dict['X_test_{}'.format(topic)] = test_attr
    
    for column in label_df.columns:

        label_encoder = OrdinalEncoder(cols=[column], handle_unknown='impute')
        label_encoder.fit(label_df[[column]])
        label_attr = label_encoder.transform(label_df[[column]])

        result_dict['Y_train_{}_{}'.format(topic, column)] = label_attr
        result_dict['Y_encoder_{}_{}'.format(topic, column)] = label_encoder
        result_dict['Y_colname_{}_{}'.format(topic, column)] = label_attr.columns
        
    return result_dict

# %%
beauty_dict = create_label(beauty_train, beauty_val, 'beauty')
fashion_dict = create_label(fashion_train, fashion_val, 'fashion')
mobile_dict = create_label(mobile_train, mobile_val, 'mobile')

# %%
topic = 'beauty'
column = 'Benefits'

X_train = beauty_dict['X_train_{}'.format(topic)]
Y_train = beauty_dict['Y_train_{}_{}'.format(topic, column)][column].values

train_idx = Y_train != 0
X_train = X_train[train_idx]
Y_train = Y_train[train_idx]

X_dev, X_val, Y_dev, Y_val = train_test_split(X_train, Y_train, test_size = 0.2)

X_test = beauty_dict['X_test_{}'.format(topic)]

dtrain = lgb.Dataset(X_train, label=Y_train)
ddev = lgb.Dataset(X_dev, label=Y_dev)
dval = lgb.Dataset(X_val, label=Y_val)
dtest = lgb.Dataset(X_test)

params = {'objective': 'multiclass',
         'eta': 0.01,
         'max_depth': 6,
         "feature_fraction":0.7,
         "bagging_fraction":0.7,
         "num_leaves": 63,
         'nthread': 6,
         'num_class': Y_train.max() + 1}

bst = lgb.train(params, ddev, num_boost_round=10, valid_sets=[ddev, dval], valid_names=['ddev','dval'], early_stopping_rounds=50)
# Out:
# [1]	ddev's multi_logloss: 2.39357	dval's multi_logloss: 2.39968
# Training until validation scores don't improve for 50 rounds.
# [2]	ddev's multi_logloss: 2.34186	dval's multi_logloss: 2.35128
# [3]	ddev's multi_logloss: 2.29831	dval's multi_logloss: 2.31035
# [4]	ddev's multi_logloss: 2.25989	dval's multi_logloss: 2.27476
# [5]	ddev's multi_logloss: 2.22429	dval's multi_logloss: 2.24133
# [6]	ddev's multi_logloss: 2.191	dval's multi_logloss: 2.21034
# [7]	ddev's multi_logloss: 2.16054	dval's multi_logloss: 2.18179
# [8]	ddev's multi_logloss: 2.13191	dval's multi_logloss: 2.15481
# [9]	ddev's multi_logloss: 2.1047	dval's multi_logloss: 2.12919
# [10]	ddev's multi_logloss: 2.07876	dval's multi_logloss: 2.10485
# Did not meet early stopping. Best iteration is:
# [10]	ddev's multi_logloss: 2.07876	dval's multi_logloss: 2.10485

# %%
Y_pred = bst.predict(X_test)
Y_class = Y_pred.argmax(1)
Y_class_df = pd.DataFrame(Y_class, columns = beauty_dict['Y_colname_beauty_Colour_group'])
Y_class_result = beauty_dict['Y_encoder_beauty_Colour_group'].inverse_transform(Y_class_df)
result = pd.DataFrame({
    'id': beauty_dict['itemid_test_beauty'].apply(lambda x : str(x) + '_Colour_group'),
    'tagging': Y_class_result['Colour_group'].values
})

# %%
def create_prediction(topic_dict, topic, column_list):
    result_dict = {}
    for column in column_list:
        print('######################################################')
        print(column)
        print('######################################################')
        X_train = topic_dict['X_train_{}'.format(topic)]
        Y_train = topic_dict['Y_train_{}_{}'.format(topic, column)][column].values
        
        train_idx = Y_train != 0
        X_train = X_train[train_idx]
        Y_train = Y_train[train_idx]
        
        X_dev, X_val, Y_dev, Y_val = train_test_split(X_train, Y_train, test_size = 0.1)
        
        X_test = topic_dict['X_test_{}'.format(topic)]
        
        ddev = lgb.Dataset(X_dev, label=Y_dev)
        dval = lgb.Dataset(X_val, label=Y_val)

        params = {'objective': 'multiclass',
                  'eta': 0.01,
                  'max_depth': 6,
                  'num_leaves': 63,
                  "feature_fraction":0.7,
                  "bagging_fraction":0.7,
                  'silent': 1,
                  'nthread': 6,
                  'num_class': Y_train.max() + 1}

        bst = lgb.train(params, ddev, num_boost_round=2000, valid_sets=[ddev, dval], valid_names=['ddev','dval'], early_stopping_rounds=50)
        Y_pred = bst.predict(X_test)
        
        Y_class = Y_pred.argmax(1)
        Y_class_df = pd.DataFrame(Y_class, columns = topic_dict['Y_colname_{}_{}'.format(topic, column)])
        Y_class_result = topic_dict['Y_encoder_{}_{}'.format(topic, column)].inverse_transform(Y_class_df)
        result = pd.DataFrame({
            'id': topic_dict['itemid_test_{}'.format(topic)].apply(lambda x : str(x) + '_{}'.format(column)),
            'tagging': Y_class_result[column].values.astype(int).astype(str)
        })
        result_dict['result_df_{}_{}'.format(topic, column)] = result
    return result_dict

# %%
beauty_result_dict = create_prediction(beauty_dict, 'beauty', ['Colour_group', 'Brand', 'Benefits',
       'Product_texture', 'Skin_type'])
fashion_result_dict = create_prediction(fashion_dict, 'fashion', ['Pattern', 'Collar Type', 'Sleeves', 'Fashion Trend',
       'Clothing Material'])
mobile_result_dict = create_prediction(mobile_dict, 'mobile', ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size'])
# Out:
# ######################################################
# Colour_group
# ######################################################
# [1]	ddev's multi_logloss: 1.50906	dval's multi_logloss: 1.5261
# Training until validation scores don't improve for 50 rounds.
# [2]	ddev's multi_logloss: 1.49382	dval's multi_logloss: 1.5104
# [3]	ddev's multi_logloss: 1.47973	dval's multi_logloss: 1.49619
# [4]	ddev's multi_logloss: 1.466	dval's multi_logloss: 1.48217
# [5]	ddev's multi_logloss: 1.45277	dval's multi_logloss: 1.46866
# [6]	ddev's multi_logloss: 1.44005	dval's multi_logloss: 1.45573
# [7]	ddev's multi_logloss: 1.42769	dval's multi_logloss: 1.44329
# [8]	ddev's multi_logloss: 1.41581	dval's multi_logloss: 1.43128
# [9]	ddev's multi_logloss: 1.40429	dval's multi_logloss: 1.41962
# [10]	ddev's multi_logloss: 1.39324	dval's multi_logloss: 1.40849
# [11]	ddev's multi_logloss: 1.38236	dval's multi_logloss: 1.39748
# [12]	ddev's multi_logloss: 1.37185	dval's multi_logloss: 1.3869
# [13]	ddev's multi_logloss: 1.36138	dval's multi_logloss: 1.37636
# [14]	ddev's multi_logloss: 1.35146	dval's multi_logloss: 1.36635
# [15]	ddev's multi_logloss: 1.34172	dval's multi_logloss: 1.35662
# [16]	ddev's multi_logloss: 1.33196	dval's multi_logloss: 1.34682
# [17]	ddev's multi_logloss: 1.32243	dval's multi_logloss: 1.33726
# [18]	ddev's multi_logloss: 1.31321	dval's multi_logloss: 1.32798
# [19]	ddev's multi_logloss: 1.304	dval's multi_logloss: 1.31876
# [20]	ddev's multi_logloss: 1.29511	dval's multi_logloss: 1.30979
# [21]	ddev's multi_logloss: 1.28638	dval's multi_logloss: 1.30106
# [22]	ddev's multi_logloss: 1.27781	dval's multi_logloss: 1.29241
# [23]	ddev's multi_logloss: 1.26944	dval's multi_logloss: 1.28402
# [24]	ddev's multi_logloss: 1.26112	dval's multi_logloss: 1.27566
# [25]	ddev's multi_logloss: 1.25312	dval's multi_logloss: 1.26768
# [26]	ddev's multi_logloss: 1.24546	dval's multi_logloss: 1.26002
# [27]	ddev's multi_logloss: 1.23764	dval's multi_logloss: 1.25229
# [28]	ddev's multi_logloss: 1.23002	dval's multi_logloss: 1.24469
# [29]	ddev's multi_logloss: 1.22264	dval's multi_logloss: 1.2373
# [30]	ddev's multi_logloss: 1.21522	dval's multi_logloss: 1.22992
# [31]	ddev's multi_logloss: 1.20809	dval's multi_logloss: 1.22281
# [32]	ddev's multi_logloss: 1.20092	dval's multi_logloss: 1.21567
# [33]	ddev's multi_logloss: 1.1938	dval's multi_logloss: 1.20858
# [34]	ddev's multi_logloss: 1.1869	dval's multi_logloss: 1.2017
# [35]	ddev's multi_logloss: 1.18005	dval's multi_logloss: 1.19486
# [36]	ddev's multi_logloss: 1.1732	dval's multi_logloss: 1.18804
# [37]	ddev's multi_logloss: 1.16652	dval's multi_logloss: 1.18139
# [38]	ddev's multi_logloss: 1.16002	dval's multi_logloss: 1.17492
# [39]	ddev's multi_logloss: 1.15359	dval's multi_logloss: 1.16852
# [40]	ddev's multi_logloss: 1.14715	dval's multi_logloss: 1.16209
# [41]	ddev's multi_logloss: 1.14097	dval's multi_logloss: 1.15594
# [42]	ddev's multi_logloss: 1.13468	dval's multi_logloss: 1.14965
# [43]	ddev's multi_logloss: 1.12858	dval's multi_logloss: 1.14357
# [44]	ddev's multi_logloss: 1.12274	dval's multi_logloss: 1.13774
# [45]	ddev's multi_logloss: 1.11669	dval's multi_logloss: 1.13172
# [46]	ddev's multi_logloss: 1.11087	dval's multi_logloss: 1.1259
# [47]	ddev's multi_logloss: 1.10501	dval's multi_logloss: 1.12003
# [48]	ddev's multi_logloss: 1.09931	dval's multi_logloss: 1.11436
# [49]	ddev's multi_logloss: 1.09378	dval's multi_logloss: 1.10887
# [50]	ddev's multi_logloss: 1.08824	dval's multi_logloss: 1.10337
# [51]	ddev's multi_logloss: 1.08272	dval's multi_logloss: 1.0979
# [52]	ddev's multi_logloss: 1.07733	dval's multi_logloss: 1.09258
# [53]	ddev's multi_logloss: 1.0718	dval's multi_logloss: 1.08708
# [54]	ddev's multi_logloss: 1.06655	dval's multi_logloss: 1.08188
# [55]	ddev's multi_logloss: 1.0613	dval's multi_logloss: 1.07664
# [56]	ddev's multi_logloss: 1.05604	dval's multi_logloss: 1.07139
# [57]	ddev's multi_logloss: 1.05083	dval's multi_logloss: 1.0662
# [58]	ddev's multi_logloss: 1.04571	dval's multi_logloss: 1.06108
# [59]	ddev's multi_logloss: 1.04065	dval's multi_logloss: 1.05613
# [60]	ddev's multi_logloss: 1.0357	dval's multi_logloss: 1.0512
# [61]	ddev's multi_logloss: 1.0309	dval's multi_logloss: 1.04641
# [62]	ddev's multi_logloss: 1.02608	dval's multi_logloss: 1.04165
# [63]	ddev's multi_logloss: 1.0213	dval's multi_logloss: 1.03694
# [64]	ddev's multi_logloss: 1.01647	dval's multi_logloss: 1.03213
# [65]	ddev's multi_logloss: 1.01173	dval's multi_logloss: 1.02741
# [66]	ddev's multi_logloss: 1.00711	dval's multi_logloss: 1.02282
# [67]	ddev's multi_logloss: 1.00261	dval's multi_logloss: 1.01835
# [68]	ddev's multi_logloss: 0.998042	dval's multi_logloss: 1.01383
# [69]	ddev's multi_logloss: 0.993648	dval's multi_logloss: 1.00948
# [70]	ddev's multi_logloss: 0.989197	dval's multi_logloss: 1.00507
# [71]	ddev's multi_logloss: 0.984772	dval's multi_logloss: 1.00064
# [72]	ddev's multi_logloss: 0.98042	dval's multi_logloss: 0.996353
# [73]	ddev's multi_logloss: 0.976191	dval's multi_logloss: 0.992175
# [74]	ddev's multi_logloss: 0.971999	dval's multi_logloss: 0.987987
# [75]	ddev's multi_logloss: 0.967823	dval's multi_logloss: 0.983883
# [76]	ddev's multi_logloss: 0.963618	dval's multi_logloss: 0.979712
# [77]	ddev's multi_logloss: 0.959463	dval's multi_logloss: 0.975643
# [78]	ddev's multi_logloss: 0.955542	dval's multi_logloss: 0.971791
# [79]	ddev's multi_logloss: 0.951541	dval's multi_logloss: 0.96779
# [80]	ddev's multi_logloss: 0.947677	dval's multi_logloss: 0.963991
# [81]	ddev's multi_logloss: 0.943736	dval's multi_logloss: 0.960094
# [82]	ddev's multi_logloss: 0.939791	dval's multi_logloss: 0.956197
# [83]	ddev's multi_logloss: 0.93596	dval's multi_logloss: 0.95238
# [84]	ddev's multi_logloss: 0.932052	dval's multi_logloss: 0.948493
# [85]	ddev's multi_logloss: 0.92828	dval's multi_logloss: 0.944762
# [86]	ddev's multi_logloss: 0.924498	dval's multi_logloss: 0.94102
# [87]	ddev's multi_logloss: 0.920849	dval's multi_logloss: 0.937456
# [88]	ddev's multi_logloss: 0.917173	dval's multi_logloss: 0.933815
# [89]	ddev's multi_logloss: 0.913487	dval's multi_logloss: 0.93019
# [90]	ddev's multi_logloss: 0.909988	dval's multi_logloss: 0.926738
# [91]	ddev's multi_logloss: 0.906418	dval's multi_logloss: 0.923211
# [92]	ddev's multi_logloss: 0.902914	dval's multi_logloss: 0.919738
# [93]	ddev's multi_logloss: 0.899373	dval's multi_logloss: 0.916231
# [94]	ddev's multi_logloss: 0.895942	dval's multi_logloss: 0.912883
# [95]	ddev's multi_logloss: 0.892502	dval's multi_logloss: 0.909541
# [96]	ddev's multi_logloss: 0.889089	dval's multi_logloss: 0.906198
# [97]	ddev's multi_logloss: 0.885656	dval's multi_logloss: 0.902839
# [98]	ddev's multi_logloss: 0.882359	dval's multi_logloss: 0.899594
# [99]	ddev's multi_logloss: 0.879102	dval's multi_logloss: 0.89643
# [100]	ddev's multi_logloss: 0.875896	dval's multi_logloss: 0.893269
# [101]	ddev's multi_logloss: 0.872652	dval's multi_logloss: 0.890068
# [102]	ddev's multi_logloss: 0.869433	dval's multi_logloss: 0.886889
# [103]	ddev's multi_logloss: 0.866257	dval's multi_logloss: 0.883782
# [104]	ddev's multi_logloss: 0.86307	dval's multi_logloss: 0.880659
# [105]	ddev's multi_logloss: 0.859941	dval's multi_logloss: 0.877588
# [106]	ddev's multi_logloss: 0.8568	dval's multi_logloss: 0.874503
# [107]	ddev's multi_logloss: 0.853704	dval's multi_logloss: 0.871428
# [108]	ddev's multi_logloss: 0.850654	dval's multi_logloss: 0.868408
# [109]	ddev's multi_logloss: 0.847658	dval's multi_logloss: 0.865456
# [110]	ddev's multi_logloss: 0.844699	dval's multi_logloss: 0.862551
# [111]	ddev's multi_logloss: 0.841797	dval's multi_logloss: 0.859722
# [112]	ddev's multi_logloss: 0.838817	dval's multi_logloss: 0.856791
# [113]	ddev's multi_logloss: 0.835874	dval's multi_logloss: 0.853919
# [114]	ddev's multi_logloss: 0.83303	dval's multi_logloss: 0.851162
# [115]	ddev's multi_logloss: 0.830207	dval's multi_logloss: 0.848383
# [116]	ddev's multi_logloss: 0.827337	dval's multi_logloss: 0.845576
# [117]	ddev's multi_logloss: 0.824645	dval's multi_logloss: 0.842912
# [118]	ddev's multi_logloss: 0.821896	dval's multi_logloss: 0.840214
# [119]	ddev's multi_logloss: 0.819181	dval's multi_logloss: 0.837538
# [120]	ddev's multi_logloss: 0.816462	dval's multi_logloss: 0.834857
# [121]	ddev's multi_logloss: 0.813764	dval's multi_logloss: 0.832233
# [122]	ddev's multi_logloss: 0.811102	dval's multi_logloss: 0.829652
# [123]	ddev's multi_logloss: 0.808526	dval's multi_logloss: 0.82713
# [124]	ddev's multi_logloss: 0.805878	dval's multi_logloss: 0.824562
# [125]	ddev's multi_logloss: 0.803309	dval's multi_logloss: 0.822023
# [126]	ddev's multi_logloss: 0.800731	dval's multi_logloss: 0.81954
# [127]	ddev's multi_logloss: 0.798138	dval's multi_logloss: 0.817013
# [128]	ddev's multi_logloss: 0.795628	dval's multi_logloss: 0.814548
# [129]	ddev's multi_logloss: 0.79305	dval's multi_logloss: 0.812035
# [130]	ddev's multi_logloss: 0.790535	dval's multi_logloss: 0.809586
# [131]	ddev's multi_logloss: 0.788023	dval's multi_logloss: 0.807133
# [132]	ddev's multi_logloss: 0.785586	dval's multi_logloss: 0.804726
# [133]	ddev's multi_logloss: 0.783188	dval's multi_logloss: 0.802377
# [134]	ddev's multi_logloss: 0.780793	dval's multi_logloss: 0.800021
# [135]	ddev's multi_logloss: 0.778359	dval's multi_logloss: 0.797669
# [136]	ddev's multi_logloss: 0.775991	dval's multi_logloss: 0.795392
# [137]	ddev's multi_logloss: 0.77362	dval's multi_logloss: 0.793063
# [138]	ddev's multi_logloss: 0.771308	dval's multi_logloss: 0.790816
# [139]	ddev's multi_logloss: 0.769014	dval's multi_logloss: 0.788587
# [140]	ddev's multi_logloss: 0.766803	dval's multi_logloss: 0.786467
# [141]	ddev's multi_logloss: 0.76458	dval's multi_logloss: 0.784293
# [142]	ddev's multi_logloss: 0.762367	dval's multi_logloss: 0.782152
# [143]	ddev's multi_logloss: 0.76016	dval's multi_logloss: 0.77999
# [144]	ddev's multi_logloss: 0.758022	dval's multi_logloss: 0.777917
# [145]	ddev's multi_logloss: 0.755792	dval's multi_logloss: 0.775749
# [146]	ddev's multi_logloss: 0.75364	dval's multi_logloss: 0.773689
# [147]	ddev's multi_logloss: 0.751484	dval's multi_logloss: 0.771595
# [148]	ddev's multi_logloss: 0.749361	dval's multi_logloss: 0.769559
# [149]	ddev's multi_logloss: 0.747307	dval's multi_logloss: 0.767549
# [150]	ddev's multi_logloss: 0.74523	dval's multi_logloss: 0.765527
# [151]	ddev's multi_logloss: 0.743123	dval's multi_logloss: 0.763488
# [152]	ddev's multi_logloss: 0.741061	dval's multi_logloss: 0.761474
# [153]	ddev's multi_logloss: 0.739026	dval's multi_logloss: 0.759509
# [154]	ddev's multi_logloss: 0.736974	dval's multi_logloss: 0.757527
# [155]	ddev's multi_logloss: 0.734872	dval's multi_logloss: 0.755485
# [156]	ddev's multi_logloss: 0.732853	dval's multi_logloss: 0.753551
# [157]	ddev's multi_logloss: 0.730898	dval's multi_logloss: 0.751673
# [158]	ddev's multi_logloss: 0.728913	dval's multi_logloss: 0.749726
# [159]	ddev's multi_logloss: 0.726989	dval's multi_logloss: 0.747848
# [160]	ddev's multi_logloss: 0.724981	dval's multi_logloss: 0.745883
# [161]	ddev's multi_logloss: 0.723034	dval's multi_logloss: 0.743988
# [162]	ddev's multi_logloss: 0.721119	dval's multi_logloss: 0.742144
# [163]	ddev's multi_logloss: 0.719252	dval's multi_logloss: 0.740308
# [164]	ddev's multi_logloss: 0.717357	dval's multi_logloss: 0.738459
# [165]	ddev's multi_logloss: 0.715424	dval's multi_logloss: 0.73659
# [166]	ddev's multi_logloss: 0.713564	dval's multi_logloss: 0.734795
# [167]	ddev's multi_logloss: 0.711732	dval's multi_logloss: 0.733015
# [168]	ddev's multi_logloss: 0.709848	dval's multi_logloss: 0.731196
# [169]	ddev's multi_logloss: 0.708097	dval's multi_logloss: 0.729492
# [170]	ddev's multi_logloss: 0.706237	dval's multi_logloss: 0.727703
# [171]	ddev's multi_logloss: 0.70446	dval's multi_logloss: 0.725993
# [172]	ddev's multi_logloss: 0.702693	dval's multi_logloss: 0.72429
# [173]	ddev's multi_logloss: 0.700963	dval's multi_logloss: 0.722632
# [174]	ddev's multi_logloss: 0.699178	dval's multi_logloss: 0.720929
# [175]	ddev's multi_logloss: 0.69738	dval's multi_logloss: 0.719198
# [176]	ddev's multi_logloss: 0.695699	dval's multi_logloss: 0.717576
# [177]	ddev's multi_logloss: 0.694002	dval's multi_logloss: 0.71595
# [178]	ddev's multi_logloss: 0.692309	dval's multi_logloss: 0.714318
# [179]	ddev's multi_logloss: 0.690724	dval's multi_logloss: 0.712775
# [180]	ddev's multi_logloss: 0.689086	dval's multi_logloss: 0.711193
# [181]	ddev's multi_logloss: 0.687428	dval's multi_logloss: 0.709619
# [182]	ddev's multi_logloss: 0.685787	dval's multi_logloss: 0.708041
# [183]	ddev's multi_logloss: 0.684123	dval's multi_logloss: 0.706492
# [184]	ddev's multi_logloss: 0.682529	dval's multi_logloss: 0.70498
# [185]	ddev's multi_logloss: 0.680959	dval's multi_logloss: 0.703475
# [186]	ddev's multi_logloss: 0.67931	dval's multi_logloss: 0.701891
# [187]	ddev's multi_logloss: 0.677657	dval's multi_logloss: 0.700296
# [188]	ddev's multi_logloss: 0.676111	dval's multi_logloss: 0.698809
# [189]	ddev's multi_logloss: 0.674554	dval's multi_logloss: 0.69734
# [190]	ddev's multi_logloss: 0.672957	dval's multi_logloss: 0.695804
# [191]	ddev's multi_logloss: 0.671425	dval's multi_logloss: 0.694334
# [192]	ddev's multi_logloss: 0.669909	dval's multi_logloss: 0.692884
# [193]	ddev's multi_logloss: 0.668384	dval's multi_logloss: 0.691418
# [194]	ddev's multi_logloss: 0.66687	dval's multi_logloss: 0.689981
# [195]	ddev's multi_logloss: 0.665357	dval's multi_logloss: 0.688524
# [196]	ddev's multi_logloss: 0.663897	dval's multi_logloss: 0.687083
# [197]	ddev's multi_logloss: 0.662451	dval's multi_logloss: 0.685672
# [198]	ddev's multi_logloss: 0.660918	dval's multi_logloss: 0.684214
# [199]	ddev's multi_logloss: 0.659454	dval's multi_logloss: 0.682808
# [200]	ddev's multi_logloss: 0.657993	dval's multi_logloss: 0.681421
# [201]	ddev's multi_logloss: 0.656549	dval's multi_logloss: 0.680041
# [202]	ddev's multi_logloss: 0.655148	dval's multi_logloss: 0.678691
# [203]	ddev's multi_logloss: 0.653713	dval's multi_logloss: 0.677333
# [204]	ddev's multi_logloss: 0.652342	dval's multi_logloss: 0.676032
# [205]	ddev's multi_logloss: 0.650916	dval's multi_logloss: 0.674697
# [206]	ddev's multi_logloss: 0.649555	dval's multi_logloss: 0.673385
# [207]	ddev's multi_logloss: 0.648209	dval's multi_logloss: 0.672087
# [208]	ddev's multi_logloss: 0.646764	dval's multi_logloss: 0.670738
# [209]	ddev's multi_logloss: 0.645443	dval's multi_logloss: 0.669467
# [210]	ddev's multi_logloss: 0.644137	dval's multi_logloss: 0.668207
# [211]	ddev's multi_logloss: 0.642814	dval's multi_logloss: 0.666937
# [212]	ddev's multi_logloss: 0.64151	dval's multi_logloss: 0.665705
# [213]	ddev's multi_logloss: 0.640212	dval's multi_logloss: 0.664472
# [214]	ddev's multi_logloss: 0.638927	dval's multi_logloss: 0.66325
# [215]	ddev's multi_logloss: 0.637686	dval's multi_logloss: 0.662057
# [216]	ddev's multi_logloss: 0.63638	dval's multi_logloss: 0.660793
# [217]	ddev's multi_logloss: 0.635098	dval's multi_logloss: 0.659586
# [218]	ddev's multi_logloss: 0.633809	dval's multi_logloss: 0.658339
# [219]	ddev's multi_logloss: 0.632482	dval's multi_logloss: 0.657095
# [220]	ddev's multi_logloss: 0.631223	dval's multi_logloss: 0.655913
# [221]	ddev's multi_logloss: 0.630034	dval's multi_logloss: 0.65479
# [222]	ddev's multi_logloss: 0.628771	dval's multi_logloss: 0.653581
# [223]	ddev's multi_logloss: 0.627527	dval's multi_logloss: 0.65239
# [224]	ddev's multi_logloss: 0.626239	dval's multi_logloss: 0.651121
# [225]	ddev's multi_logloss: 0.625042	dval's multi_logloss: 0.649988
# [226]	ddev's multi_logloss: 0.623854	dval's multi_logloss: 0.648873
# [227]	ddev's multi_logloss: 0.622628	dval's multi_logloss: 0.647736
# [228]	ddev's multi_logloss: 0.62144	dval's multi_logloss: 0.646633
# [229]	ddev's multi_logloss: 0.620242	dval's multi_logloss: 0.645517
# [230]	ddev's multi_logloss: 0.61907	dval's multi_logloss: 0.644417
# [231]	ddev's multi_logloss: 0.617865	dval's multi_logloss: 0.643283
# [232]	ddev's multi_logloss: 0.6167	dval's multi_logloss: 0.642182
# [233]	ddev's multi_logloss: 0.615492	dval's multi_logloss: 0.641056
# [234]	ddev's multi_logloss: 0.614331	dval's multi_logloss: 0.639971
# [235]	ddev's multi_logloss: 0.613206	dval's multi_logloss: 0.638903
# [236]	ddev's multi_logloss: 0.612062	dval's multi_logloss: 0.637855
# [237]	ddev's multi_logloss: 0.610934	dval's multi_logloss: 0.636788
# [238]	ddev's multi_logloss: 0.609796	dval's multi_logloss: 0.635717
# [239]	ddev's multi_logloss: 0.608693	dval's multi_logloss: 0.634707
# [240]	ddev's multi_logloss: 0.607545	dval's multi_logloss: 0.633645
# [241]	ddev's multi_logloss: 0.606423	dval's multi_logloss: 0.632618
# [242]	ddev's multi_logloss: 0.605298	dval's multi_logloss: 0.631597
# [243]	ddev's multi_logloss: 0.60419	dval's multi_logloss: 0.630542
# [244]	ddev's multi_logloss: 0.603118	dval's multi_logloss: 0.629554
# [245]	ddev's multi_logloss: 0.601996	dval's multi_logloss: 0.628528
# [246]	ddev's multi_logloss: 0.600909	dval's multi_logloss: 0.627524
# [247]	ddev's multi_logloss: 0.599863	dval's multi_logloss: 0.626559
# [248]	ddev's multi_logloss: 0.598823	dval's multi_logloss: 0.625596
# [249]	ddev's multi_logloss: 0.597748	dval's multi_logloss: 0.624601
# [250]	ddev's multi_logloss: 0.596643	dval's multi_logloss: 0.623617
# [251]	ddev's multi_logloss: 0.595619	dval's multi_logloss: 0.62268
# [252]	ddev's multi_logloss: 0.594598	dval's multi_logloss: 0.621713
# [253]	ddev's multi_logloss: 0.59358	dval's multi_logloss: 0.620812
# [254]	ddev's multi_logloss: 0.592538	dval's multi_logloss: 0.619834
# [255]	ddev's multi_logloss: 0.59153	dval's multi_logloss: 0.618913
# [256]	ddev's multi_logloss: 0.590558	dval's multi_logloss: 0.61803
# [257]	ddev's multi_logloss: 0.589581	dval's multi_logloss: 0.617134
# [258]	ddev's multi_logloss: 0.58854	dval's multi_logloss: 0.616184
# [259]	ddev's multi_logloss: 0.587549	dval's multi_logloss: 0.615282
# [260]	ddev's multi_logloss: 0.586562	dval's multi_logloss: 0.614364
# [261]	ddev's multi_logloss: 0.585573	dval's multi_logloss: 0.613437
# [262]	ddev's multi_logloss: 0.584593	dval's multi_logloss: 0.612525
# [263]	ddev's multi_logloss: 0.583616	dval's multi_logloss: 0.611646
# [264]	ddev's multi_logloss: 0.582677	dval's multi_logloss: 0.610786
# [265]	ddev's multi_logloss: 0.581702	dval's multi_logloss: 0.609895
# [266]	ddev's multi_logloss: 0.580761	dval's multi_logloss: 0.609018
# [267]	ddev's multi_logloss: 0.579841	dval's multi_logloss: 0.608182
# [268]	ddev's multi_logloss: 0.578919	dval's multi_logloss: 0.607316
# [269]	ddev's multi_logloss: 0.577972	dval's multi_logloss: 0.606439
# [270]	ddev's multi_logloss: 0.577	dval's multi_logloss: 0.605573
# [271]	ddev's multi_logloss: 0.576079	dval's multi_logloss: 0.60475
# [272]	ddev's multi_logloss: 0.575133	dval's multi_logloss: 0.603898
# [273]	ddev's multi_logloss: 0.574178	dval's multi_logloss: 0.60301
# [274]	ddev's multi_logloss: 0.573307	dval's multi_logloss: 0.602205
# [275]	ddev's multi_logloss: 0.572409	dval's multi_logloss: 0.601376
# [276]	ddev's multi_logloss: 0.571515	dval's multi_logloss: 0.600532
# [277]	ddev's multi_logloss: 0.57063	dval's multi_logloss: 0.599718
# [278]	ddev's multi_logloss: 0.569751	dval's multi_logloss: 0.59892
# [279]	ddev's multi_logloss: 0.56885	dval's multi_logloss: 0.598115
# [280]	ddev's multi_logloss: 0.568022	dval's multi_logloss: 0.597353
# [281]	ddev's multi_logloss: 0.567137	dval's multi_logloss: 0.596545
# [282]	ddev's multi_logloss: 0.566258	dval's multi_logloss: 0.595761
# [283]	ddev's multi_logloss: 0.565387	dval's multi_logloss: 0.594951
# [284]	ddev's multi_logloss: 0.564524	dval's multi_logloss: 0.594188
# [285]	ddev's multi_logloss: 0.563675	dval's multi_logloss: 0.59342
# [286]	ddev's multi_logloss: 0.562844	dval's multi_logloss: 0.592647
# [287]	ddev's multi_logloss: 0.561995	dval's multi_logloss: 0.591889
# [288]	ddev's multi_logloss: 0.561154	dval's multi_logloss: 0.591105
# [289]	ddev's multi_logloss: 0.560309	dval's multi_logloss: 0.590327
# [290]	ddev's multi_logloss: 0.559494	dval's multi_logloss: 0.589608
# [291]	ddev's multi_logloss: 0.558675	dval's multi_logloss: 0.588859
# [292]	ddev's multi_logloss: 0.557832	dval's multi_logloss: 0.588083
# [293]	ddev's multi_logloss: 0.557003	dval's multi_logloss: 0.587329
# [294]	ddev's multi_logloss: 0.556192	dval's multi_logloss: 0.586594
# [295]	ddev's multi_logloss: 0.555398	dval's multi_logloss: 0.585897
# [296]	ddev's multi_logloss: 0.554584	dval's multi_logloss: 0.585181
# [297]	ddev's multi_logloss: 0.553807	dval's multi_logloss: 0.584486
# [298]	ddev's multi_logloss: 0.553062	dval's multi_logloss: 0.583809
# [299]	ddev's multi_logloss: 0.552257	dval's multi_logloss: 0.583077
# [300]	ddev's multi_logloss: 0.551476	dval's multi_logloss: 0.5824
# [301]	ddev's multi_logloss: 0.550693	dval's multi_logloss: 0.581697
# [302]	ddev's multi_logloss: 0.549944	dval's multi_logloss: 0.580995
# [303]	ddev's multi_logloss: 0.549159	dval's multi_logloss: 0.580279
# [304]	ddev's multi_logloss: 0.548389	dval's multi_logloss: 0.579594
# [305]	ddev's multi_logloss: 0.547645	dval's multi_logloss: 0.578945
# [306]	ddev's multi_logloss: 0.546897	dval's multi_logloss: 0.578275
# [307]	ddev's multi_logloss: 0.546154	dval's multi_logloss: 0.577596
# [308]	ddev's multi_logloss: 0.545424	dval's multi_logloss: 0.576914
# [309]	ddev's multi_logloss: 0.544659	dval's multi_logloss: 0.576246
# [310]	ddev's multi_logloss: 0.543941	dval's multi_logloss: 0.575595
# [311]	ddev's multi_logloss: 0.543205	dval's multi_logloss: 0.57496
# [312]	ddev's multi_logloss: 0.542459	dval's multi_logloss: 0.574303
# [313]	ddev's multi_logloss: 0.541727	dval's multi_logloss: 0.573648
# [314]	ddev's multi_logloss: 0.541007	dval's multi_logloss: 0.572993
# [315]	ddev's multi_logloss: 0.540276	dval's multi_logloss: 0.572344
# [316]	ddev's multi_logloss: 0.539594	dval's multi_logloss: 0.57172
# [317]	ddev's multi_logloss: 0.538888	dval's multi_logloss: 0.571098
# [318]	ddev's multi_logloss: 0.538183	dval's multi_logloss: 0.570468
# [319]	ddev's multi_logloss: 0.537482	dval's multi_logloss: 0.569831
# [320]	ddev's multi_logloss: 0.536761	dval's multi_logloss: 0.569199
# [321]	ddev's multi_logloss: 0.536051	dval's multi_logloss: 0.568593
# [322]	ddev's multi_logloss: 0.535377	dval's multi_logloss: 0.567969
# [323]	ddev's multi_logloss: 0.534634	dval's multi_logloss: 0.567306
# [324]	ddev's multi_logloss: 0.533925	dval's multi_logloss: 0.566679
# [325]	ddev's multi_logloss: 0.533224	dval's multi_logloss: 0.566044
# [326]	ddev's multi_logloss: 0.532545	dval's multi_logloss: 0.565433
# [327]	ddev's multi_logloss: 0.531883	dval's multi_logloss: 0.564868
# [328]	ddev's multi_logloss: 0.531161	dval's multi_logloss: 0.564225
# [329]	ddev's multi_logloss: 0.530498	dval's multi_logloss: 0.563646
# [330]	ddev's multi_logloss: 0.529816	dval's multi_logloss: 0.563034
# [331]	ddev's multi_logloss: 0.529154	dval's multi_logloss: 0.562437
# [332]	ddev's multi_logloss: 0.528491	dval's multi_logloss: 0.561835
# [333]	ddev's multi_logloss: 0.527885	dval's multi_logloss: 0.561305
# [334]	ddev's multi_logloss: 0.527228	dval's multi_logloss: 0.560721
# [335]	ddev's multi_logloss: 0.526579	dval's multi_logloss: 0.560137
# [336]	ddev's multi_logloss: 0.5259	dval's multi_logloss: 0.559562
# [337]	ddev's multi_logloss: 0.525258	dval's multi_logloss: 0.558982
# [338]	ddev's multi_logloss: 0.524616	dval's multi_logloss: 0.55841
# [339]	ddev's multi_logloss: 0.52396	dval's multi_logloss: 0.557834
# [340]	ddev's multi_logloss: 0.523315	dval's multi_logloss: 0.557256
# [341]	ddev's multi_logloss: 0.522706	dval's multi_logloss: 0.55671
# [342]	ddev's multi_logloss: 0.522094	dval's multi_logloss: 0.556192
# [343]	ddev's multi_logloss: 0.521478	dval's multi_logloss: 0.555654
# [344]	ddev's multi_logloss: 0.520848	dval's multi_logloss: 0.555106
# [345]	ddev's multi_logloss: 0.520219	dval's multi_logloss: 0.55457
# [346]	ddev's multi_logloss: 0.519594	dval's multi_logloss: 0.554034
# [347]	ddev's multi_logloss: 0.51901	dval's multi_logloss: 0.55352
# [348]	ddev's multi_logloss: 0.518388	dval's multi_logloss: 0.552965
# [349]	ddev's multi_logloss: 0.5178	dval's multi_logloss: 0.552427
# [350]	ddev's multi_logloss: 0.517224	dval's multi_logloss: 0.551917
# [351]	ddev's multi_logloss: 0.516652	dval's multi_logloss: 0.551396
# [352]	ddev's multi_logloss: 0.516048	dval's multi_logloss: 0.550854
# [353]	ddev's multi_logloss: 0.515486	dval's multi_logloss: 0.550355
# [354]	ddev's multi_logloss: 0.514906	dval's multi_logloss: 0.549846
# [355]	ddev's multi_logloss: 0.514306	dval's multi_logloss: 0.549325
# [356]	ddev's multi_logloss: 0.513684	dval's multi_logloss: 0.548805
# [357]	ddev's multi_logloss: 0.513126	dval's multi_logloss: 0.548316
# [358]	ddev's multi_logloss: 0.512558	dval's multi_logloss: 0.547811
# [359]	ddev's multi_logloss: 0.511925	dval's multi_logloss: 0.54727
# [360]	ddev's multi_logloss: 0.511349	dval's multi_logloss: 0.54677
# [361]	ddev's multi_logloss: 0.510778	dval's multi_logloss: 0.546274
# [362]	ddev's multi_logloss: 0.510257	dval's multi_logloss: 0.545807
# [363]	ddev's multi_logloss: 0.50973	dval's multi_logloss: 0.545345
# [364]	ddev's multi_logloss: 0.509131	dval's multi_logloss: 0.544836
# [365]	ddev's multi_logloss: 0.508602	dval's multi_logloss: 0.544356
# [366]	ddev's multi_logloss: 0.508014	dval's multi_logloss: 0.543853
# [367]	ddev's multi_logloss: 0.507439	dval's multi_logloss: 0.543349
# [368]	ddev's multi_logloss: 0.506882	dval's multi_logloss: 0.542866
# [369]	ddev's multi_logloss: 0.506334	dval's multi_logloss: 0.542397
# [370]	ddev's multi_logloss: 0.505835	dval's multi_logloss: 0.541967
# [371]	ddev's multi_logloss: 0.505284	dval's multi_logloss: 0.541506
# [372]	ddev's multi_logloss: 0.50472	dval's multi_logloss: 0.541028
# [373]	ddev's multi_logloss: 0.504179	dval's multi_logloss: 0.540559
# [374]	ddev's multi_logloss: 0.50362	dval's multi_logloss: 0.540073
# [375]	ddev's multi_logloss: 0.503078	dval's multi_logloss: 0.539616
# [376]	ddev's multi_logloss: 0.502523	dval's multi_logloss: 0.539153
# [377]	ddev's multi_logloss: 0.501982	dval's multi_logloss: 0.538659
# [378]	ddev's multi_logloss: 0.50146	dval's multi_logloss: 0.538208
# [379]	ddev's multi_logloss: 0.500908	dval's multi_logloss: 0.537735
# [380]	ddev's multi_logloss: 0.500371	dval's multi_logloss: 0.537305
# [381]	ddev's multi_logloss: 0.499853	dval's multi_logloss: 0.536871
# [382]	ddev's multi_logloss: 0.499298	dval's multi_logloss: 0.536414
# [383]	ddev's multi_logloss: 0.498733	dval's multi_logloss: 0.535923
# [384]	ddev's multi_logloss: 0.498227	dval's multi_logloss: 0.53549
# [385]	ddev's multi_logloss: 0.497726	dval's multi_logloss: 0.535081
# [386]	ddev's multi_logloss: 0.497182	dval's multi_logloss: 0.534619
# [387]	ddev's multi_logloss: 0.496686	dval's multi_logloss: 0.534205
# [388]	ddev's multi_logloss: 0.496159	dval's multi_logloss: 0.533746
# [389]	ddev's multi_logloss: 0.495647	dval's multi_logloss: 0.533314
# [390]	ddev's multi_logloss: 0.495101	dval's multi_logloss: 0.532848
# [391]	ddev's multi_logloss: 0.494607	dval's multi_logloss: 0.532435
# [392]	ddev's multi_logloss: 0.494096	dval's multi_logloss: 0.532007
# [393]	ddev's multi_logloss: 0.493619	dval's multi_logloss: 0.531613
# [394]	ddev's multi_logloss: 0.493157	dval's multi_logloss: 0.531209
# [395]	ddev's multi_logloss: 0.492685	dval's multi_logloss: 0.530819
# [396]	ddev's multi_logloss: 0.492188	dval's multi_logloss: 0.530383
# [397]	ddev's multi_logloss: 0.491694	dval's multi_logloss: 0.529955
# [398]	ddev's multi_logloss: 0.491252	dval's multi_logloss: 0.52958
# [399]	ddev's multi_logloss: 0.490731	dval's multi_logloss: 0.52914
# [400]	ddev's multi_logloss: 0.49025	dval's multi_logloss: 0.52874
# [401]	ddev's multi_logloss: 0.489784	dval's multi_logloss: 0.528344
# [402]	ddev's multi_logloss: 0.48927	dval's multi_logloss: 0.527897
# [403]	ddev's multi_logloss: 0.488773	dval's multi_logloss: 0.527478
# [404]	ddev's multi_logloss: 0.488323	dval's multi_logloss: 0.527112
# [405]	ddev's multi_logloss: 0.487811	dval's multi_logloss: 0.526698
# [406]	ddev's multi_logloss: 0.48736	dval's multi_logloss: 0.526313
# [407]	ddev's multi_logloss: 0.486838	dval's multi_logloss: 0.525885
# [408]	ddev's multi_logloss: 0.486412	dval's multi_logloss: 0.525512
# [409]	ddev's multi_logloss: 0.485926	dval's multi_logloss: 0.525081
# [410]	ddev's multi_logloss: 0.485428	dval's multi_logloss: 0.524657
# [411]	ddev's multi_logloss: 0.484962	dval's multi_logloss: 0.524259
# [412]	ddev's multi_logloss: 0.484511	dval's multi_logloss: 0.523875
# [413]	ddev's multi_logloss: 0.484036	dval's multi_logloss: 0.523497
# [414]	ddev's multi_logloss: 0.483581	dval's multi_logloss: 0.523103
# [415]	ddev's multi_logloss: 0.483114	dval's multi_logloss: 0.522689
# [416]	ddev's multi_logloss: 0.482672	dval's multi_logloss: 0.522309
# [417]	ddev's multi_logloss: 0.482196	dval's multi_logloss: 0.521939
# [418]	ddev's multi_logloss: 0.481722	dval's multi_logloss: 0.521542
# [419]	ddev's multi_logloss: 0.481229	dval's multi_logloss: 0.521145
# [420]	ddev's multi_logloss: 0.480769	dval's multi_logloss: 0.520757
# [421]	ddev's multi_logloss: 0.480318	dval's multi_logloss: 0.520385
# [422]	ddev's multi_logloss: 0.479874	dval's multi_logloss: 0.52003
# [423]	ddev's multi_logloss: 0.479424	dval's multi_logloss: 0.519667
# [424]	ddev's multi_logloss: 0.478994	dval's multi_logloss: 0.519293
# [425]	ddev's multi_logloss: 0.478521	dval's multi_logloss: 0.518906
# [426]	ddev's multi_logloss: 0.478091	dval's multi_logloss: 0.518555
# [427]	ddev's multi_logloss: 0.477635	dval's multi_logloss: 0.51817
# [428]	ddev's multi_logloss: 0.477218	dval's multi_logloss: 0.517806
# [429]	ddev's multi_logloss: 0.476751	dval's multi_logloss: 0.517421
# [430]	ddev's multi_logloss: 0.476328	dval's multi_logloss: 0.517075
# [431]	ddev's multi_logloss: 0.475883	dval's multi_logloss: 0.516688
# [432]	ddev's multi_logloss: 0.475455	dval's multi_logloss: 0.516334
# [433]	ddev's multi_logloss: 0.475005	dval's multi_logloss: 0.51596
# [434]	ddev's multi_logloss: 0.474548	dval's multi_logloss: 0.515589
# [435]	ddev's multi_logloss: 0.474145	dval's multi_logloss: 0.515252
# [436]	ddev's multi_logloss: 0.473662	dval's multi_logloss: 0.514851
# [437]	ddev's multi_logloss: 0.473206	dval's multi_logloss: 0.514497
# [438]	ddev's multi_logloss: 0.472754	dval's multi_logloss: 0.51415
# [439]	ddev's multi_logloss: 0.472287	dval's multi_logloss: 0.513758
# [440]	ddev's multi_logloss: 0.471831	dval's multi_logloss: 0.51337
# [441]	ddev's multi_logloss: 0.471425	dval's multi_logloss: 0.513035
# [442]	ddev's multi_logloss: 0.471023	dval's multi_logloss: 0.512722
# [443]	ddev's multi_logloss: 0.470576	dval's multi_logloss: 0.512377
# [444]	ddev's multi_logloss: 0.470176	dval's multi_logloss: 0.512028
# [445]	ddev's multi_logloss: 0.469792	dval's multi_logloss: 0.51169
# [446]	ddev's multi_logloss: 0.469364	dval's multi_logloss: 0.51136
# [447]	ddev's multi_logloss: 0.468912	dval's multi_logloss: 0.510982
# [448]	ddev's multi_logloss: 0.468498	dval's multi_logloss: 0.510633
# [449]	ddev's multi_logloss: 0.468061	dval's multi_logloss: 0.510292
# [450]	ddev's multi_logloss: 0.467656	dval's multi_logloss: 0.509936
# [451]	ddev's multi_logloss: 0.467234	dval's multi_logloss: 0.50958
# [452]	ddev's multi_logloss: 0.466827	dval's multi_logloss: 0.509253
# [453]	ddev's multi_logloss: 0.466386	dval's multi_logloss: 0.508883
# [454]	ddev's multi_logloss: 0.465981	dval's multi_logloss: 0.50856
# [455]	ddev's multi_logloss: 0.465544	dval's multi_logloss: 0.508212
# [456]	ddev's multi_logloss: 0.465157	dval's multi_logloss: 0.507903
# [457]	ddev's multi_logloss: 0.464781	dval's multi_logloss: 0.507607
# [458]	ddev's multi_logloss: 0.464385	dval's multi_logloss: 0.507286
# [459]	ddev's multi_logloss: 0.464002	dval's multi_logloss: 0.506984
# [460]	ddev's multi_logloss: 0.463591	dval's multi_logloss: 0.506662
# [461]	ddev's multi_logloss: 0.463215	dval's multi_logloss: 0.50636
# [462]	ddev's multi_logloss: 0.462757	dval's multi_logloss: 0.505996
# [463]	ddev's multi_logloss: 0.462343	dval's multi_logloss: 0.505663
# [464]	ddev's multi_logloss: 0.461966	dval's multi_logloss: 0.505347
# [465]	ddev's multi_logloss: 0.46158	dval's multi_logloss: 0.505037
# [466]	ddev's multi_logloss: 0.461157	dval's multi_logloss: 0.504691
# [467]	ddev's multi_logloss: 0.460759	dval's multi_logloss: 0.504376
# [468]	ddev's multi_logloss: 0.460361	dval's multi_logloss: 0.504042
# [469]	ddev's multi_logloss: 0.459961	dval's multi_logloss: 0.503735
# [470]	ddev's multi_logloss: 0.45958	dval's multi_logloss: 0.503417
# [471]	ddev's multi_logloss: 0.459163	dval's multi_logloss: 0.503082
# [472]	ddev's multi_logloss: 0.458729	dval's multi_logloss: 0.502735
# [473]	ddev's multi_logloss: 0.458381	dval's multi_logloss: 0.502455
# [474]	ddev's multi_logloss: 0.458007	dval's multi_logloss: 0.502157
# [475]	ddev's multi_logloss: 0.457612	dval's multi_logloss: 0.50184
# [476]	ddev's multi_logloss: 0.457203	dval's multi_logloss: 0.501518
# [477]	ddev's multi_logloss: 0.45679	dval's multi_logloss: 0.501202
# [478]	ddev's multi_logloss: 0.456393	dval's multi_logloss: 0.500893
# [479]	ddev's multi_logloss: 0.456054	dval's multi_logloss: 0.500624
# [480]	ddev's multi_logloss: 0.455652	dval's multi_logloss: 0.500304
# [481]	ddev's multi_logloss: 0.45528	dval's multi_logloss: 0.500012
# [482]	ddev's multi_logloss: 0.454887	dval's multi_logloss: 0.499697
# [483]	ddev's multi_logloss: 0.454514	dval's multi_logloss: 0.499393
# [484]	ddev's multi_logloss: 0.454141	dval's multi_logloss: 0.499098
# [485]	ddev's multi_logloss: 0.453756	dval's multi_logloss: 0.498813
# [486]	ddev's multi_logloss: 0.453383	dval's multi_logloss: 0.498542
# [487]	ddev's multi_logloss: 0.452981	dval's multi_logloss: 0.498223
# [488]	ddev's multi_logloss: 0.452626	dval's multi_logloss: 0.497957
# [489]	ddev's multi_logloss: 0.452244	dval's multi_logloss: 0.497657
# [490]	ddev's multi_logloss: 0.451852	dval's multi_logloss: 0.497355
# [491]	ddev's multi_logloss: 0.451486	dval's multi_logloss: 0.497054
# [492]	ddev's multi_logloss: 0.451122	dval's multi_logloss: 0.496773
# [493]	ddev's multi_logloss: 0.45072	dval's multi_logloss: 0.496436
# [494]	ddev's multi_logloss: 0.450349	dval's multi_logloss: 0.496154
# [495]	ddev's multi_logloss: 0.449964	dval's multi_logloss: 0.49587
# [496]	ddev's multi_logloss: 0.449623	dval's multi_logloss: 0.495586
# [497]	ddev's multi_logloss: 0.449295	dval's multi_logloss: 0.495325
# [498]	ddev's multi_logloss: 0.448933	dval's multi_logloss: 0.495041
# [499]	ddev's multi_logloss: 0.448569	dval's multi_logloss: 0.494758
# [500]	ddev's multi_logloss: 0.448224	dval's multi_logloss: 0.494502
# [501]	ddev's multi_logloss: 0.447871	dval's multi_logloss: 0.494225
# [502]	ddev's multi_logloss: 0.447523	dval's multi_logloss: 0.493962
# [503]	ddev's multi_logloss: 0.447183	dval's multi_logloss: 0.493671
# [504]	ddev's multi_logloss: 0.446827	dval's multi_logloss: 0.493386
# [505]	ddev's multi_logloss: 0.44646	dval's multi_logloss: 0.493093
# [506]	ddev's multi_logloss: 0.446094	dval's multi_logloss: 0.492805
# [507]	ddev's multi_logloss: 0.445751	dval's multi_logloss: 0.492538
# [508]	ddev's multi_logloss: 0.445425	dval's multi_logloss: 0.492284
# [509]	ddev's multi_logloss: 0.44504	dval's multi_logloss: 0.49199
# [510]	ddev's multi_logloss: 0.444647	dval's multi_logloss: 0.491677
# [511]	ddev's multi_logloss: 0.444305	dval's multi_logloss: 0.491402
# [512]	ddev's multi_logloss: 0.443954	dval's multi_logloss: 0.491123
# [513]	ddev's multi_logloss: 0.443626	dval's multi_logloss: 0.490864
# [514]	ddev's multi_logloss: 0.443285	dval's multi_logloss: 0.490618
# [515]	ddev's multi_logloss: 0.442883	dval's multi_logloss: 0.490299
# [516]	ddev's multi_logloss: 0.442529	dval's multi_logloss: 0.490048
# [517]	ddev's multi_logloss: 0.442178	dval's multi_logloss: 0.489786
# [518]	ddev's multi_logloss: 0.441826	dval's multi_logloss: 0.489519
# [519]	ddev's multi_logloss: 0.441466	dval's multi_logloss: 0.489233
# [520]	ddev's multi_logloss: 0.441133	dval's multi_logloss: 0.488963
# [521]	ddev's multi_logloss: 0.440772	dval's multi_logloss: 0.488678
# [522]	ddev's multi_logloss: 0.440423	dval's multi_logloss: 0.488422
# [523]	ddev's multi_logloss: 0.440064	dval's multi_logloss: 0.488146
# [524]	ddev's multi_logloss: 0.439673	dval's multi_logloss: 0.487848
# [525]	ddev's multi_logloss: 0.439332	dval's multi_logloss: 0.487586
# [526]	ddev's multi_logloss: 0.438991	dval's multi_logloss: 0.487298
# [527]	ddev's multi_logloss: 0.438664	dval's multi_logloss: 0.487057
# [528]	ddev's multi_logloss: 0.438343	dval's multi_logloss: 0.486783
# [529]	ddev's multi_logloss: 0.438017	dval's multi_logloss: 0.486554
# [530]	ddev's multi_logloss: 0.437659	dval's multi_logloss: 0.48628
# [531]	ddev's multi_logloss: 0.437308	dval's multi_logloss: 0.486011
# [532]	ddev's multi_logloss: 0.436955	dval's multi_logloss: 0.485742
# [533]	ddev's multi_logloss: 0.436615	dval's multi_logloss: 0.485483
# [534]	ddev's multi_logloss: 0.436298	dval's multi_logloss: 0.485223
# [535]	ddev's multi_logloss: 0.435983	dval's multi_logloss: 0.484969
# [536]	ddev's multi_logloss: 0.435686	dval's multi_logloss: 0.484755
# [537]	ddev's multi_logloss: 0.435348	dval's multi_logloss: 0.484483
# [538]	ddev's multi_logloss: 0.435038	dval's multi_logloss: 0.484247
# [539]	ddev's multi_logloss: 0.434701	dval's multi_logloss: 0.483997
# [540]	ddev's multi_logloss: 0.434376	dval's multi_logloss: 0.483738
# [541]	ddev's multi_logloss: 0.434036	dval's multi_logloss: 0.483483
# [542]	ddev's multi_logloss: 0.433711	dval's multi_logloss: 0.483241
# [543]	ddev's multi_logloss: 0.433363	dval's multi_logloss: 0.482956
# [544]	ddev's multi_logloss: 0.433069	dval's multi_logloss: 0.482735
# [545]	ddev's multi_logloss: 0.432736	dval's multi_logloss: 0.48247
# [546]	ddev's multi_logloss: 0.432426	dval's multi_logloss: 0.482237
# [547]	ddev's multi_logloss: 0.432072	dval's multi_logloss: 0.481967
# [548]	ddev's multi_logloss: 0.431769	dval's multi_logloss: 0.481731
# [549]	ddev's multi_logloss: 0.431462	dval's multi_logloss: 0.481524
# [550]	ddev's multi_logloss: 0.431142	dval's multi_logloss: 0.481295
# [551]	ddev's multi_logloss: 0.430839	dval's multi_logloss: 0.481048
# [552]	ddev's multi_logloss: 0.430529	dval's multi_logloss: 0.480822
# [553]	ddev's multi_logloss: 0.430233	dval's multi_logloss: 0.480611
# [554]	ddev's multi_logloss: 0.429933	dval's multi_logloss: 0.480379
# [555]	ddev's multi_logloss: 0.429648	dval's multi_logloss: 0.480166
# [556]	ddev's multi_logloss: 0.429329	dval's multi_logloss: 0.47994
# [557]	ddev's multi_logloss: 0.429024	dval's multi_logloss: 0.479722
# [558]	ddev's multi_logloss: 0.428719	dval's multi_logloss: 0.47949
# [559]	ddev's multi_logloss: 0.428391	dval's multi_logloss: 0.479243
# [560]	ddev's multi_logloss: 0.428093	dval's multi_logloss: 0.479013
# [561]	ddev's multi_logloss: 0.427806	dval's multi_logloss: 0.47879
# [562]	ddev's multi_logloss: 0.427516	dval's multi_logloss: 0.478597
# [563]	ddev's multi_logloss: 0.427201	dval's multi_logloss: 0.47836
# [564]	ddev's multi_logloss: 0.426904	dval's multi_logloss: 0.478124
# [565]	ddev's multi_logloss: 0.426623	dval's multi_logloss: 0.477917
# [566]	ddev's multi_logloss: 0.426331	dval's multi_logloss: 0.477682
# [567]	ddev's multi_logloss: 0.426015	dval's multi_logloss: 0.477441
# [568]	ddev's multi_logloss: 0.425726	dval's multi_logloss: 0.477232
# [569]	ddev's multi_logloss: 0.42544	dval's multi_logloss: 0.477033
# [570]	ddev's multi_logloss: 0.425125	dval's multi_logloss: 0.476799
# [571]	ddev's multi_logloss: 0.424842	dval's multi_logloss: 0.476587
# [572]	ddev's multi_logloss: 0.424537	dval's multi_logloss: 0.476356
# [573]	ddev's multi_logloss: 0.424236	dval's multi_logloss: 0.476142
# [574]	ddev's multi_logloss: 0.42394	dval's multi_logloss: 0.475909
# [575]	ddev's multi_logloss: 0.423654	dval's multi_logloss: 0.475702
# [576]	ddev's multi_logloss: 0.423304	dval's multi_logloss: 0.47544
# [577]	ddev's multi_logloss: 0.423009	dval's multi_logloss: 0.47524
# [578]	ddev's multi_logloss: 0.4227	dval's multi_logloss: 0.475019
# [579]	ddev's multi_logloss: 0.422395	dval's multi_logloss: 0.474784
# [580]	ddev's multi_logloss: 0.422076	dval's multi_logloss: 0.474548
# [581]	ddev's multi_logloss: 0.42178	dval's multi_logloss: 0.474321
# [582]	ddev's multi_logloss: 0.421472	dval's multi_logloss: 0.474084
# [583]	ddev's multi_logloss: 0.421169	dval's multi_logloss: 0.473887
# [584]	ddev's multi_logloss: 0.420891	dval's multi_logloss: 0.47368
# [585]	ddev's multi_logloss: 0.420627	dval's multi_logloss: 0.473475
# [586]	ddev's multi_logloss: 0.420344	dval's multi_logloss: 0.473275
# [587]	ddev's multi_logloss: 0.420056	dval's multi_logloss: 0.473048
# [588]	ddev's multi_logloss: 0.419758	dval's multi_logloss: 0.472824
# [589]	ddev's multi_logloss: 0.419452	dval's multi_logloss: 0.472587
# [590]	ddev's multi_logloss: 0.419181	dval's multi_logloss: 0.472401
# [591]	ddev's multi_logloss: 0.418861	dval's multi_logloss: 0.472183
# [592]	ddev's multi_logloss: 0.418585	dval's multi_logloss: 0.471965
# [593]	ddev's multi_logloss: 0.418313	dval's multi_logloss: 0.471785
# [594]	ddev's multi_logloss: 0.418018	dval's multi_logloss: 0.47157
# [595]	ddev's multi_logloss: 0.417718	dval's multi_logloss: 0.471337
# [596]	ddev's multi_logloss: 0.41741	dval's multi_logloss: 0.47109
# [597]	ddev's multi_logloss: 0.417167	dval's multi_logloss: 0.470913
# [598]	ddev's multi_logloss: 0.416871	dval's multi_logloss: 0.470706
# [599]	ddev's multi_logloss: 0.416586	dval's multi_logloss: 0.470504
# [600]	ddev's multi_logloss: 0.416285	dval's multi_logloss: 0.470304
# [601]	ddev's multi_logloss: 0.416011	dval's multi_logloss: 0.470109
# [602]	ddev's multi_logloss: 0.415711	dval's multi_logloss: 0.469891
# [603]	ddev's multi_logloss: 0.415448	dval's multi_logloss: 0.469704
# [604]	ddev's multi_logloss: 0.415156	dval's multi_logloss: 0.469496
# [605]	ddev's multi_logloss: 0.414902	dval's multi_logloss: 0.469319
# [606]	ddev's multi_logloss: 0.414633	dval's multi_logloss: 0.469132
# [607]	ddev's multi_logloss: 0.414369	dval's multi_logloss: 0.468943
# [608]	ddev's multi_logloss: 0.414104	dval's multi_logloss: 0.468746
# [609]	ddev's multi_logloss: 0.413815	dval's multi_logloss: 0.468536
# [610]	ddev's multi_logloss: 0.413545	dval's multi_logloss: 0.468354
# [611]	ddev's multi_logloss: 0.413247	dval's multi_logloss: 0.468133
# [612]	ddev's multi_logloss: 0.412976	dval's multi_logloss: 0.467943
# [613]	ddev's multi_logloss: 0.412673	dval's multi_logloss: 0.467743
# [614]	ddev's multi_logloss: 0.412405	dval's multi_logloss: 0.467543
# [615]	ddev's multi_logloss: 0.412121	dval's multi_logloss: 0.467328
# [616]	ddev's multi_logloss: 0.411878	dval's multi_logloss: 0.467139
# [617]	ddev's multi_logloss: 0.411622	dval's multi_logloss: 0.466948
# [618]	ddev's multi_logloss: 0.411355	dval's multi_logloss: 0.466743
# [619]	ddev's multi_logloss: 0.411062	dval's multi_logloss: 0.466546
# [620]	ddev's multi_logloss: 0.41079	dval's multi_logloss: 0.466338
# [621]	ddev's multi_logloss: 0.410492	dval's multi_logloss: 0.466127
# [622]	ddev's multi_logloss: 0.410198	dval's multi_logloss: 0.465919
# [623]	ddev's multi_logloss: 0.409943	dval's multi_logloss: 0.465729
# [624]	ddev's multi_logloss: 0.409688	dval's multi_logloss: 0.465536
# [625]	ddev's multi_logloss: 0.409437	dval's multi_logloss: 0.465346
# [626]	ddev's multi_logloss: 0.409196	dval's multi_logloss: 0.465188
# [627]	ddev's multi_logloss: 0.408907	dval's multi_logloss: 0.464978
# [628]	ddev's multi_logloss: 0.408633	dval's multi_logloss: 0.464785
# [629]	ddev's multi_logloss: 0.408364	dval's multi_logloss: 0.464584
# [630]	ddev's multi_logloss: 0.408101	dval's multi_logloss: 0.464393
# [631]	ddev's multi_logloss: 0.407835	dval's multi_logloss: 0.464197
# [632]	ddev's multi_logloss: 0.40759	dval's multi_logloss: 0.464015
# [633]	ddev's multi_logloss: 0.407308	dval's multi_logloss: 0.463811
# [634]	ddev's multi_logloss: 0.407032	dval's multi_logloss: 0.463639
# [635]	ddev's multi_logloss: 0.406781	dval's multi_logloss: 0.463477
# [636]	ddev's multi_logloss: 0.406504	dval's multi_logloss: 0.463281
# [637]	ddev's multi_logloss: 0.406222	dval's multi_logloss: 0.463087
# [638]	ddev's multi_logloss: 0.405972	dval's multi_logloss: 0.462918
# [639]	ddev's multi_logloss: 0.40568	dval's multi_logloss: 0.462719
# [640]	ddev's multi_logloss: 0.405425	dval's multi_logloss: 0.462541
# [641]	ddev's multi_logloss: 0.405156	dval's multi_logloss: 0.462336
# [642]	ddev's multi_logloss: 0.404894	dval's multi_logloss: 0.46217
# [643]	ddev's multi_logloss: 0.404621	dval's multi_logloss: 0.461958
# [644]	ddev's multi_logloss: 0.404344	dval's multi_logloss: 0.461761
# [645]	ddev's multi_logloss: 0.404113	dval's multi_logloss: 0.461602
# [646]	ddev's multi_logloss: 0.403847	dval's multi_logloss: 0.461421
# [647]	ddev's multi_logloss: 0.403601	dval's multi_logloss: 0.461245
# [648]	ddev's multi_logloss: 0.403309	dval's multi_logloss: 0.461035
# [649]	ddev's multi_logloss: 0.403077	dval's multi_logloss: 0.460875
# [650]	ddev's multi_logloss: 0.402869	dval's multi_logloss: 0.460741
# [651]	ddev's multi_logloss: 0.402622	dval's multi_logloss: 0.460566
# [652]	ddev's multi_logloss: 0.402369	dval's multi_logloss: 0.460361
# [653]	ddev's multi_logloss: 0.402087	dval's multi_logloss: 0.460175
# [654]	ddev's multi_logloss: 0.401816	dval's multi_logloss: 0.459995
# [655]	ddev's multi_logloss: 0.40157	dval's multi_logloss: 0.459818
# [656]	ddev's multi_logloss: 0.401312	dval's multi_logloss: 0.45964
# [657]	ddev's multi_logloss: 0.401059	dval's multi_logloss: 0.459452
# [658]	ddev's multi_logloss: 0.400801	dval's multi_logloss: 0.459262
# [659]	ddev's multi_logloss: 0.40057	dval's multi_logloss: 0.459102
# [660]	ddev's multi_logloss: 0.400339	dval's multi_logloss: 0.458949
# [661]	ddev's multi_logloss: 0.40007	dval's multi_logloss: 0.458757
# [662]	ddev's multi_logloss: 0.399813	dval's multi_logloss: 0.458593
# [663]	ddev's multi_logloss: 0.399578	dval's multi_logloss: 0.458427
# [664]	ddev's multi_logloss: 0.39931	dval's multi_logloss: 0.458224
# [665]	ddev's multi_logloss: 0.399077	dval's multi_logloss: 0.45807
# [666]	ddev's multi_logloss: 0.398801	dval's multi_logloss: 0.45788
# [667]	ddev's multi_logloss: 0.398544	dval's multi_logloss: 0.457705
# [668]	ddev's multi_logloss: 0.398318	dval's multi_logloss: 0.457551
# [669]	ddev's multi_logloss: 0.398057	dval's multi_logloss: 0.457348
# [670]	ddev's multi_logloss: 0.397791	dval's multi_logloss: 0.457156
# [671]	ddev's multi_logloss: 0.397545	dval's multi_logloss: 0.457007
# [672]	ddev's multi_logloss: 0.397294	dval's multi_logloss: 0.456833
# [673]	ddev's multi_logloss: 0.397064	dval's multi_logloss: 0.456682
# [674]	ddev's multi_logloss: 0.396799	dval's multi_logloss: 0.456511
# [675]	ddev's multi_logloss: 0.396566	dval's multi_logloss: 0.45634
# [676]	ddev's multi_logloss: 0.396316	dval's multi_logloss: 0.456169
# [677]	ddev's multi_logloss: 0.396072	dval's multi_logloss: 0.456002
# [678]	ddev's multi_logloss: 0.395807	dval's multi_logloss: 0.455794
# [679]	ddev's multi_logloss: 0.395549	dval's multi_logloss: 0.455623
# [680]	ddev's multi_logloss: 0.395295	dval's multi_logloss: 0.45546
# [681]	ddev's multi_logloss: 0.395044	dval's multi_logloss: 0.455292
# [682]	ddev's multi_logloss: 0.394798	dval's multi_logloss: 0.455141
# [683]	ddev's multi_logloss: 0.394549	dval's multi_logloss: 0.454965
# [684]	ddev's multi_logloss: 0.394306	dval's multi_logloss: 0.454806
# [685]	ddev's multi_logloss: 0.394045	dval's multi_logloss: 0.454627
# [686]	ddev's multi_logloss: 0.393802	dval's multi_logloss: 0.454469
# [687]	ddev's multi_logloss: 0.393584	dval's multi_logloss: 0.454323
# [688]	ddev's multi_logloss: 0.393337	dval's multi_logloss: 0.454158
# [689]	ddev's multi_logloss: 0.393096	dval's multi_logloss: 0.453988
# [690]	ddev's multi_logloss: 0.39287	dval's multi_logloss: 0.45385
# [691]	ddev's multi_logloss: 0.39262	dval's multi_logloss: 0.453679
# [692]	ddev's multi_logloss: 0.392397	dval's multi_logloss: 0.453531
# [693]	ddev's multi_logloss: 0.392149	dval's multi_logloss: 0.453352
# [694]	ddev's multi_logloss: 0.391924	dval's multi_logloss: 0.453216
# [695]	ddev's multi_logloss: 0.391711	dval's multi_logloss: 0.453084
# [696]	ddev's multi_logloss: 0.391447	dval's multi_logloss: 0.452895
# [697]	ddev's multi_logloss: 0.391198	dval's multi_logloss: 0.452726
# [698]	ddev's multi_logloss: 0.39097	dval's multi_logloss: 0.452576
# [699]	ddev's multi_logloss: 0.390733	dval's multi_logloss: 0.452398
# [700]	ddev's multi_logloss: 0.390501	dval's multi_logloss: 0.452228
# [701]	ddev's multi_logloss: 0.390277	dval's multi_logloss: 0.452082
# [702]	ddev's multi_logloss: 0.390061	dval's multi_logloss: 0.451942
# [703]	ddev's multi_logloss: 0.389845	dval's multi_logloss: 0.451789
# [704]	ddev's multi_logloss: 0.389593	dval's multi_logloss: 0.451606
# [705]	ddev's multi_logloss: 0.389379	dval's multi_logloss: 0.451466
# [706]	ddev's multi_logloss: 0.389175	dval's multi_logloss: 0.451333
# [707]	ddev's multi_logloss: 0.388917	dval's multi_logloss: 0.45117
# [708]	ddev's multi_logloss: 0.388688	dval's multi_logloss: 0.451002
# [709]	ddev's multi_logloss: 0.388447	dval's multi_logloss: 0.450849
# ...
# [20]	ddev's multi_logloss: 2.17047	dval's multi_logloss: 2.35829
# [21]	ddev's multi_logloss: 2.13214	dval's multi_logloss: 2.32137
# [22]	ddev's multi_logloss: 2.09531	dval's multi_logloss: 2.28602
# [23]	ddev's multi_logloss: 2.06008	dval's multi_logloss: 2.2522
# [24]	ddev's multi_logloss: 2.02596	dval's multi_logloss: 2.21938
# [25]	ddev's multi_logloss: 1.99294	dval's multi_logloss: 2.18769
# [26]	ddev's multi_logloss: 1.96115	dval's multi_logloss: 2.15711
# [27]	ddev's multi_logloss: 1.9304	dval's multi_logloss: 2.12755
# [28]	ddev's multi_logloss: 1.90097	dval's multi_logloss: 2.0992
# [29]	ddev's multi_logloss: 1.87227	dval's multi_logloss: 2.07158
# [30]	ddev's multi_logloss: 1.84427	dval's multi_logloss: 2.04464
# [31]	ddev's multi_logloss: 1.8169	dval's multi_logloss: 2.01837
# [32]	ddev's multi_logloss: 1.79043	dval's multi_logloss: 1.99292
# [33]	ddev's multi_logloss: 1.76527	dval's multi_logloss: 1.96903
# [34]	ddev's multi_logloss: 1.73965	dval's multi_logloss: 1.94381
# [35]	ddev's multi_logloss: 1.71516	dval's multi_logloss: 1.92027
# [36]	ddev's multi_logloss: 1.69151	dval's multi_logloss: 1.89782
# [37]	ddev's multi_logloss: 1.6684	dval's multi_logloss: 1.87547
# [38]	ddev's multi_logloss: 1.64577	dval's multi_logloss: 1.85365
# [39]	ddev's multi_logloss: 1.62403	dval's multi_logloss: 1.83269
# [40]	ddev's multi_logloss: 1.6026	dval's multi_logloss: 1.81204
# [41]	ddev's multi_logloss: 1.58175	dval's multi_logloss: 1.79204
# [42]	ddev's multi_logloss: 1.5612	dval's multi_logloss: 1.7722
# [43]	ddev's multi_logloss: 1.54203	dval's multi_logloss: 1.75463
# [44]	ddev's multi_logloss: 1.52134	dval's multi_logloss: 1.73439
# [45]	ddev's multi_logloss: 1.50205	dval's multi_logloss: 1.71573
# [46]	ddev's multi_logloss: 1.48322	dval's multi_logloss: 1.69752
# [47]	ddev's multi_logloss: 1.46621	dval's multi_logloss: 1.68196
# [48]	ddev's multi_logloss: 1.44725	dval's multi_logloss: 1.66381
# [49]	ddev's multi_logloss: 1.42956	dval's multi_logloss: 1.64698
# [50]	ddev's multi_logloss: 1.41199	dval's multi_logloss: 1.63012
# [51]	ddev's multi_logloss: 1.39535	dval's multi_logloss: 1.61383
# [52]	ddev's multi_logloss: 1.3786	dval's multi_logloss: 1.59761
# [53]	ddev's multi_logloss: 1.36216	dval's multi_logloss: 1.58172
# [54]	ddev's multi_logloss: 1.34681	dval's multi_logloss: 1.56707
# [55]	ddev's multi_logloss: 1.33093	dval's multi_logloss: 1.55174
# [56]	ddev's multi_logloss: 1.31538	dval's multi_logloss: 1.53676
# [57]	ddev's multi_logloss: 1.30006	dval's multi_logloss: 1.52193
# [58]	ddev's multi_logloss: 1.28497	dval's multi_logloss: 1.50731
# [59]	ddev's multi_logloss: 1.27013	dval's multi_logloss: 1.49297
# [60]	ddev's multi_logloss: 1.25562	dval's multi_logloss: 1.47893
# [61]	ddev's multi_logloss: 1.24142	dval's multi_logloss: 1.46524
# [62]	ddev's multi_logloss: 1.22856	dval's multi_logloss: 1.45294
# [63]	ddev's multi_logloss: 1.2139	dval's multi_logloss: 1.43919
# [64]	ddev's multi_logloss: 1.20022	dval's multi_logloss: 1.42606
# [65]	ddev's multi_logloss: 1.18682	dval's multi_logloss: 1.41311
# [66]	ddev's multi_logloss: 1.17493	dval's multi_logloss: 1.40256
# [67]	ddev's multi_logloss: 1.16101	dval's multi_logloss: 1.38878
# [68]	ddev's multi_logloss: 1.14813	dval's multi_logloss: 1.37647
# [69]	ddev's multi_logloss: 1.13545	dval's multi_logloss: 1.3639
# [70]	ddev's multi_logloss: 1.12306	dval's multi_logloss: 1.35185
# [71]	ddev's multi_logloss: 1.11098	dval's multi_logloss: 1.34013
# [72]	ddev's multi_logloss: 1.0992	dval's multi_logloss: 1.32833
# [73]	ddev's multi_logloss: 1.08741	dval's multi_logloss: 1.31689
# [74]	ddev's multi_logloss: 1.07576	dval's multi_logloss: 1.30553
# [75]	ddev's multi_logloss: 1.06435	dval's multi_logloss: 1.2944
# [76]	ddev's multi_logloss: 1.05307	dval's multi_logloss: 1.28347
# [77]	ddev's multi_logloss: 1.04196	dval's multi_logloss: 1.27266
# [78]	ddev's multi_logloss: 1.03095	dval's multi_logloss: 1.26193
# [79]	ddev's multi_logloss: 1.02015	dval's multi_logloss: 1.25139
# [80]	ddev's multi_logloss: 1.00954	dval's multi_logloss: 1.24104
# [81]	ddev's multi_logloss: 0.999105	dval's multi_logloss: 1.23083
# [82]	ddev's multi_logloss: 0.988784	dval's multi_logloss: 1.22074
# [83]	ddev's multi_logloss: 0.978569	dval's multi_logloss: 1.21079
# [84]	ddev's multi_logloss: 0.968712	dval's multi_logloss: 1.20117
# [85]	ddev's multi_logloss: 0.958734	dval's multi_logloss: 1.19142
# [86]	ddev's multi_logloss: 0.948934	dval's multi_logloss: 1.18182
# [87]	ddev's multi_logloss: 0.939263	dval's multi_logloss: 1.17236
# [88]	ddev's multi_logloss: 0.92977	dval's multi_logloss: 1.16305
# [89]	ddev's multi_logloss: 0.920323	dval's multi_logloss: 1.15379
# [90]	ddev's multi_logloss: 0.910993	dval's multi_logloss: 1.14464
# [91]	ddev's multi_logloss: 0.901859	dval's multi_logloss: 1.13569
# [92]	ddev's multi_logloss: 0.892754	dval's multi_logloss: 1.12673
# [93]	ddev's multi_logloss: 0.883775	dval's multi_logloss: 1.11793
# [94]	ddev's multi_logloss: 0.874948	dval's multi_logloss: 1.10929
# [95]	ddev's multi_logloss: 0.866219	dval's multi_logloss: 1.10074
# [96]	ddev's multi_logloss: 0.857635	dval's multi_logloss: 1.09231
# [97]	ddev's multi_logloss: 0.849162	dval's multi_logloss: 1.08399
# [98]	ddev's multi_logloss: 0.840784	dval's multi_logloss: 1.07577
# [99]	ddev's multi_logloss: 0.832553	dval's multi_logloss: 1.06769
# [100]	ddev's multi_logloss: 0.824358	dval's multi_logloss: 1.05964
# [101]	ddev's multi_logloss: 0.816277	dval's multi_logloss: 1.05168
# [102]	ddev's multi_logloss: 0.808317	dval's multi_logloss: 1.04384
# [103]	ddev's multi_logloss: 0.800404	dval's multi_logloss: 1.03606
# [104]	ddev's multi_logloss: 0.792575	dval's multi_logloss: 1.02836
# [105]	ddev's multi_logloss: 0.784855	dval's multi_logloss: 1.02075
# [106]	ddev's multi_logloss: 0.777216	dval's multi_logloss: 1.01323
# [107]	ddev's multi_logloss: 0.769727	dval's multi_logloss: 1.00585
# [108]	ddev's multi_logloss: 0.762273	dval's multi_logloss: 0.998506
# [109]	ddev's multi_logloss: 0.754958	dval's multi_logloss: 0.99128
# [110]	ddev's multi_logloss: 0.747763	dval's multi_logloss: 0.984188
# [111]	ddev's multi_logloss: 0.740603	dval's multi_logloss: 0.977114
# [112]	ddev's multi_logloss: 0.733524	dval's multi_logloss: 0.970149
# [113]	ddev's multi_logloss: 0.726475	dval's multi_logloss: 0.9632
# [114]	ddev's multi_logloss: 0.719577	dval's multi_logloss: 0.956393
# [115]	ddev's multi_logloss: 0.712734	dval's multi_logloss: 0.949631
# [116]	ddev's multi_logloss: 0.70596	dval's multi_logloss: 0.942935
# [117]	ddev's multi_logloss: 0.69923	dval's multi_logloss: 0.936304
# [118]	ddev's multi_logloss: 0.692619	dval's multi_logloss: 0.929779
# [119]	ddev's multi_logloss: 0.686081	dval's multi_logloss: 0.923298
# [120]	ddev's multi_logloss: 0.679611	dval's multi_logloss: 0.916899
# [121]	ddev's multi_logloss: 0.673222	dval's multi_logloss: 0.910534
# [122]	ddev's multi_logloss: 0.666862	dval's multi_logloss: 0.904259
# [123]	ddev's multi_logloss: 0.660631	dval's multi_logloss: 0.898078
# [124]	ddev's multi_logloss: 0.654489	dval's multi_logloss: 0.891984
# [125]	ddev's multi_logloss: 0.648414	dval's multi_logloss: 0.885981
# [126]	ddev's multi_logloss: 0.642392	dval's multi_logloss: 0.879993
# [127]	ddev's multi_logloss: 0.63641	dval's multi_logloss: 0.874056
# [128]	ddev's multi_logloss: 0.630537	dval's multi_logloss: 0.868218
# [129]	ddev's multi_logloss: 0.624727	dval's multi_logloss: 0.862437
# [130]	ddev's multi_logloss: 0.618973	dval's multi_logloss: 0.856721
# [131]	ddev's multi_logloss: 0.613271	dval's multi_logloss: 0.851061
# [132]	ddev's multi_logloss: 0.607621	dval's multi_logloss: 0.845433
# [133]	ddev's multi_logloss: 0.602024	dval's multi_logloss: 0.839857
# [134]	ddev's multi_logloss: 0.596539	dval's multi_logloss: 0.834381
# [135]	ddev's multi_logloss: 0.591097	dval's multi_logloss: 0.828969
# [136]	ddev's multi_logloss: 0.585667	dval's multi_logloss: 0.82353
# [137]	ddev's multi_logloss: 0.580305	dval's multi_logloss: 0.81818
# [138]	ddev's multi_logloss: 0.575042	dval's multi_logloss: 0.812942
# [139]	ddev's multi_logloss: 0.569786	dval's multi_logloss: 0.807693
# [140]	ddev's multi_logloss: 0.564605	dval's multi_logloss: 0.802522
# [141]	ddev's multi_logloss: 0.559459	dval's multi_logloss: 0.79738
# [142]	ddev's multi_logloss: 0.55434	dval's multi_logloss: 0.792282
# [143]	ddev's multi_logloss: 0.54929	dval's multi_logloss: 0.787229
# [144]	ddev's multi_logloss: 0.544344	dval's multi_logloss: 0.782272
# [145]	ddev's multi_logloss: 0.539425	dval's multi_logloss: 0.777362
# [146]	ddev's multi_logloss: 0.534548	dval's multi_logloss: 0.772508
# [147]	ddev's multi_logloss: 0.529724	dval's multi_logloss: 0.767685
# [148]	ddev's multi_logloss: 0.524942	dval's multi_logloss: 0.762902
# [149]	ddev's multi_logloss: 0.520217	dval's multi_logloss: 0.758166
# [150]	ddev's multi_logloss: 0.515521	dval's multi_logloss: 0.753472
# [151]	ddev's multi_logloss: 0.510872	dval's multi_logloss: 0.748834
# [152]	ddev's multi_logloss: 0.506339	dval's multi_logloss: 0.744276
# [153]	ddev's multi_logloss: 0.501788	dval's multi_logloss: 0.739714
# [154]	ddev's multi_logloss: 0.497299	dval's multi_logloss: 0.735227
# [155]	ddev's multi_logloss: 0.492834	dval's multi_logloss: 0.73074
# [156]	ddev's multi_logloss: 0.488433	dval's multi_logloss: 0.726284
# [157]	ddev's multi_logloss: 0.484076	dval's multi_logloss: 0.72191
# [158]	ddev's multi_logloss: 0.479757	dval's multi_logloss: 0.717557
# [159]	ddev's multi_logloss: 0.475517	dval's multi_logloss: 0.713307
# [160]	ddev's multi_logloss: 0.471271	dval's multi_logloss: 0.70903
# [161]	ddev's multi_logloss: 0.467101	dval's multi_logloss: 0.704824
# [162]	ddev's multi_logloss: 0.463005	dval's multi_logloss: 0.700674
# [163]	ddev's multi_logloss: 0.458912	dval's multi_logloss: 0.696563
# [164]	ddev's multi_logloss: 0.454887	dval's multi_logloss: 0.692496
# [165]	ddev's multi_logloss: 0.450884	dval's multi_logloss: 0.688491
# [166]	ddev's multi_logloss: 0.446921	dval's multi_logloss: 0.684484
# [167]	ddev's multi_logloss: 0.443021	dval's multi_logloss: 0.68053
# [168]	ddev's multi_logloss: 0.439135	dval's multi_logloss: 0.676583
# [169]	ddev's multi_logloss: 0.435273	dval's multi_logloss: 0.672692
# [170]	ddev's multi_logloss: 0.431432	dval's multi_logloss: 0.668802
# [171]	ddev's multi_logloss: 0.427642	dval's multi_logloss: 0.664965
# [172]	ddev's multi_logloss: 0.423932	dval's multi_logloss: 0.661191
# [173]	ddev's multi_logloss: 0.420243	dval's multi_logloss: 0.657457
# [174]	ddev's multi_logloss: 0.416571	dval's multi_logloss: 0.653722
# [175]	ddev's multi_logloss: 0.412926	dval's multi_logloss: 0.650032
# [176]	ddev's multi_logloss: 0.409377	dval's multi_logloss: 0.646435
# [177]	ddev's multi_logloss: 0.405786	dval's multi_logloss: 0.642812
# [178]	ddev's multi_logloss: 0.402245	dval's multi_logloss: 0.639205
# [179]	ddev's multi_logloss: 0.398757	dval's multi_logloss: 0.635661
# [180]	ddev's multi_logloss: 0.395273	dval's multi_logloss: 0.632117
# [181]	ddev's multi_logloss: 0.391845	dval's multi_logloss: 0.628636
# [182]	ddev's multi_logloss: 0.388439	dval's multi_logloss: 0.625182
# [183]	ddev's multi_logloss: 0.385082	dval's multi_logloss: 0.621761
# [184]	ddev's multi_logloss: 0.381765	dval's multi_logloss: 0.618381
# [185]	ddev's multi_logloss: 0.378487	dval's multi_logloss: 0.615061
# [186]	ddev's multi_logloss: 0.375215	dval's multi_logloss: 0.611729
# [187]	ddev's multi_logloss: 0.371977	dval's multi_logloss: 0.608444
# [188]	ddev's multi_logloss: 0.368776	dval's multi_logloss: 0.605177
# [189]	ddev's multi_logloss: 0.365612	dval's multi_logloss: 0.601951
# [190]	ddev's multi_logloss: 0.362466	dval's multi_logloss: 0.598745
# [191]	ddev's multi_logloss: 0.359394	dval's multi_logloss: 0.595617
# [192]	ddev's multi_logloss: 0.356316	dval's multi_logloss: 0.592478
# [193]	ddev's multi_logloss: 0.353289	dval's multi_logloss: 0.589365
# [194]	ddev's multi_logloss: 0.350265	dval's multi_logloss: 0.586282
# [195]	ddev's multi_logloss: 0.347271	dval's multi_logloss: 0.583214
# [196]	ddev's multi_logloss: 0.344309	dval's multi_logloss: 0.580183
# [197]	ddev's multi_logloss: 0.341357	dval's multi_logloss: 0.577157
# [198]	ddev's multi_logloss: 0.33847	dval's multi_logloss: 0.574203
# [199]	ddev's multi_logloss: 0.335578	dval's multi_logloss: 0.571237
# [200]	ddev's multi_logloss: 0.332708	dval's multi_logloss: 0.568289
# [201]	ddev's multi_logloss: 0.329886	dval's multi_logloss: 0.565398
# [202]	ddev's multi_logloss: 0.327114	dval's multi_logloss: 0.562559
# [203]	ddev's multi_logloss: 0.324334	dval's multi_logloss: 0.559716
# [204]	ddev's multi_logloss: 0.32156	dval's multi_logloss: 0.556882
# [205]	ddev's multi_logloss: 0.318823	dval's multi_logloss: 0.554072
# [206]	ddev's multi_logloss: 0.316112	dval's multi_logloss: 0.551295
# [207]	ddev's multi_logloss: 0.313428	dval's multi_logloss: 0.548524
# [208]	ddev's multi_logloss: 0.310786	dval's multi_logloss: 0.545795
# [209]	ddev's multi_logloss: 0.308174	dval's multi_logloss: 0.543108
# [210]	ddev's multi_logloss: 0.305553	dval's multi_logloss: 0.540425
# [211]	ddev's multi_logloss: 0.302968	dval's multi_logloss: 0.537769
# [212]	ddev's multi_logloss: 0.300418	dval's multi_logloss: 0.535125
# [213]	ddev's multi_logloss: 0.297918	dval's multi_logloss: 0.532528
# [214]	ddev's multi_logloss: 0.295412	dval's multi_logloss: 0.529933
# [215]	ddev's multi_logloss: 0.292928	dval's multi_logloss: 0.527373
# [216]	ddev's multi_logloss: 0.290458	dval's multi_logloss: 0.524831
# [217]	ddev's multi_logloss: 0.288015	dval's multi_logloss: 0.522293
# [218]	ddev's multi_logloss: 0.285601	dval's multi_logloss: 0.51979
# [219]	ddev's multi_logloss: 0.283211	dval's multi_logloss: 0.517298
# [220]	ddev's multi_logloss: 0.280848	dval's multi_logloss: 0.514859
# [221]	ddev's multi_logloss: 0.278485	dval's multi_logloss: 0.512419
# [222]	ddev's multi_logloss: 0.27615	dval's multi_logloss: 0.509995
# [223]	ddev's multi_logloss: 0.273838	dval's multi_logloss: 0.507601
# [224]	ddev's multi_logloss: 0.271571	dval's multi_logloss: 0.505244
# [225]	ddev's multi_logloss: 0.26932	dval's multi_logloss: 0.502898
# [226]	ddev's multi_logloss: 0.267081	dval's multi_logloss: 0.500558
# [227]	ddev's multi_logloss: 0.264876	dval's multi_logloss: 0.498264
# [228]	ddev's multi_logloss: 0.262668	dval's multi_logloss: 0.495966
# [229]	ddev's multi_logloss: 0.260489	dval's multi_logloss: 0.493708
# [230]	ddev's multi_logloss: 0.258314	dval's multi_logloss: 0.491442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-de6cabcc8bab> in <module>
#       1 beauty_result_dict = create_prediction(beauty_dict, 'beauty', ['Colour_group', 'Brand', 'Benefits',
# ----> 2        'Product_texture', 'Skin_type'])
#       3 #fashion_result_dict = create_prediction(fashion_dict, 'fashion', ['Pattern', 'Collar Type', 'Sleeves', 'Fashion Trend',
#       4 #       'Clothing Material'])
#       5 #mobile_result_dict = create_prediction(mobile_dict, 'mobile', ['Operating System', 'Features',
#
# <ipython-input-22-72ecd18c321d> in create_prediction(topic_dict, topic, column_list)
#      29                   'num_class': Y_train.max() + 1}
#      30
# ---> 31         bst = lgb.train(params, ddev, num_boost_round=2000, valid_sets=[ddev, dval], valid_names=['ddev','dval'], early_stopping_rounds=50)
#      32         Y_pred = bst.predict(X_test)
#      33
#
# ~/git/shopee_data_science/.venv/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# ~/git/shopee_data_science/.venv/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
beauty_result = pd.concat([beauty_result_dict[x] for x in beauty_result_dict.keys()])
fashion_result = pd.concat([fashion_result_dict[x] for x in fashion_result_dict.keys()])
mobile_result = pd.concat([mobile_result_dict[x] for x in mobile_result_dict.keys()])

# %%
beauty_result.loc[beauty_result['tagging'] == '0', 'tagging'] = ''
fashion_result.loc[fashion_result['tagging'] == '0', 'tagging'] = ''
mobile_result.loc[mobile_result['tagging'] == '0', 'tagging'] = ''

# %%
beauty_result.to_csv(os.path.join(result_path, 'beauty_result.csv'), index=False)
fashion_result.to_csv(os.path.join(result_path, 'fashion_result.csv'), index=False)
mobile_result.to_csv(os.path.join(result_path, 'mobile_result.csv'), index=False)
